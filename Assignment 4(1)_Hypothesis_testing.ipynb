# %% [markdown]
# # HYPOTHESIS TESTING

# %% [markdown]
# ### 2. Calculate the Test Statistic:

# %%
import math
import numpy as np

# %%
x_bar = 3050
s_mean = 600
pop_mean = 1000 + 5 * 600
std = 5*25
n = 25
alpha = 0.05

# %%
print(pop_mean)
# Out:
# 4000

# %%
print(std)
# Out:
# 125

# %%
se = std/math.sqrt(n)

# %%
test = (x_bar-pop_mean)/se

# %%
print(test)
# Out:
# -38.0

# %% [markdown]
# ### 3. Determine the Critical Value:

# %%
# Explaination: 
alpha = 0.05 
# inside the z table inside the column 0.5 the value is Z value 0.9505 and the row is 1.6

# %%
# critical_value = (z_value = 0.9505) = 1.6

# %%
critical_value = 1.6

# %% [markdown]
# ## 4. Decision

# %%
if test > critical_value:
    print("Reject H0 (evidence that mean cost is higher).")
else:
    print("Do not reject H0 (no evidence that mean cost is higher).")
# Out:
# Do not reject H0 (no evidence that mean cost is higher).

# %% [markdown]
# ## 5. Conclusion

# %%
There is no evidence that the weekly operating costs are higher than the model suggests.
