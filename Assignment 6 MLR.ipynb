# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy.stats import zscore

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("ToyotaCorolla - MLR.csv")
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986    Diesel  90          0  2000      3          4
# 1  13750         23  72937    Diesel  90          0  2000      3          4
# 2  13950         24  41711    Diesel  90          0  2000      3          4
# 3  14950         26  48000    Diesel  90          0  2000      3          4
# 4  13750         30  38500    Diesel  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna(df[col].mode()[0])
    else:
        df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Price'], kde=True)
plt.title("Distribution of Car Price")
plt.show()

# %%
num_cols = df.select_dtypes(include = ['int64','float64']).columns

corr_matrix = df[num_cols].corr()
corr_matrix

plt.figure(figsize = (12,7))
sns.heatmap(corr_matrix, annot = True, cmap ='coolwarm', linewidth = 0.5)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df = pd.get_dummies(df, columns=['Fuel_Type'], drop_first=True)
df.head()
# Out:
#    Price  Age_08_04     KM  HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0  13500         23  46986  90          0  2000      3          4      5
# 1  13750         23  72937  90          0  2000      3          4      5
# 2  13950         24  41711  90          0  2000      3          4      5
# 3  14950         26  48000  90          0  2000      3          4      5
# 4  13750         30  38500  90          0  2000      3          4      5
#
#    Weight  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0    1165              True             False
# 1    1165              True             False
# 2    1165              True             False
# 3    1165              True             False
# 4    1170              True             False

# %%
X = df.drop('Price', axis=1)
y = df['Price']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': lr.coef_
})
coeff_df
# Out:
#              Feature   Coefficient
# 0          Age_08_04 -2.246662e+03
# 1                 KM -6.085706e+02
# 2                 HP  2.102533e+02
# 3          Automatic  3.413608e+01
# 4                 cc -1.288507e+01
# 5              Doors -5.743684e+01
# 6          Cylinders  2.842171e-13
# 7              Gears  1.039463e+02
# 8             Weight  1.362139e+03
# 9   Fuel_Type_Diesel -2.127088e+01
# 10  Fuel_Type_Petrol  4.451027e+02

# %%
y_pred = lr.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 990.887273919397
# MSE: 2203043.8231437034
# RMSE: 1484.2654153296517
# R2 Score: 0.8348888040611082

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
ridge_pred = ridge.predict(X_test)

print("R2 Score (Ridge):", r2_score(y_test, ridge_pred))
# Out:
# R2 Score (Ridge): 0.8350658145414693

# %%
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.01)

# %%
lasso_pred = lasso.predict(X_test)

print("R2 Score (Lasso):", r2_score(y_test, lasso_pred))
# Out:
# R2 Score (Lasso): 0.8348911358891581

# %%
lasso_coeff = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': lasso.coef_})
lasso_coeff
# Out:
#              Feature  Coefficient
# 0          Age_08_04 -2246.660530
# 1                 KM  -608.575952
# 2                 HP   210.264651
# 3          Automatic    34.130327
# 4                 cc   -12.875258
# 5              Doors   -57.418612
# 6          Cylinders     0.000000
# 7              Gears   103.939944
# 8             Weight  1362.095174
# 9   Fuel_Type_Diesel   -21.246004
# 10  Fuel_Type_Petrol   445.088507

# %% [markdown]
# ## Interview Question

# %% [markdown]
# 1.What is Normalization & Standardization and how is it helpful?
#
# Normalisation:
# Rescales data to a fixed range (0–1) so that all features contribute equally, especially useful for distance-based models.
#
# Standardization:
# Transforms data to have mean 0 and standard deviation 1, improving model stability and convergence.

# %% [markdown]
# 2.What techniques can be used to address multicollinearity in multiple linear regression?
#
# Multicollinearity occurs when independent variables are highly correlated, leading to unstable coefficients.
#
# It can be handled by:
#
# Removing correlated features
#
# Using Variance Inflation Factor (VIF)
#
# Applying PCA
#
# Using regularization techniques like Ridge or Lasso
